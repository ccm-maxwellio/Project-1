# %% [markdown]
# # Title: Data Cleaning for Survery Results
# # Name: Maxwell Yung
# # Date: 2/23/25

# %% [markdown]
# Import pandas, read in file

# %%
import pandas as pd
datafile = "Non-Majors Survey Results - Fall 2024.csv"
df = pd.read_csv(datafile)

# %% [markdown]
# Explore dataset using built in functions of pandas

# %%
df

# %%
df.describe

# %%
df.columns

# %%
df.shape

# %%
df.dtypes

# %%
df.head()

# %%
df.tail()

# %%
df.sample()

# %%
df.info()

# %% [markdown]
# ## Now we need to clean up the data. First, we'll start with renaming columns (code from GitHub CoPilot)

# %% [markdown]
# This is the dataset + columns before any manipulation

# %%
df
# Out:
#                      Timestamp   Which course are you currently enrolled in?  \
# 0   2024/09/10 10:47:35 AM AST  CMP 126 Computer Technology and Applications
# 1   2024/09/10 11:00:05 AM AST  CMP 126 Computer Technology and Applications
# 2   2024/09/10 11:02:51 AM AST  CMP 126 Computer Technology and Applications
# 3   2024/09/10 11:05:25 AM AST  CMP 126 Computer Technology and Applications
# 4    2024/09/10 8:37:36 PM AST         CMP 101 Computer Information Literacy
# ..                         ...                                           ...
# 87  2024/09/20 10:55:34 PM AST         CMP 101 Computer Information Literacy
# 88  2024/09/20 11:02:45 PM AST  CMP 126 Computer Technology and Applications
# 89  2024/09/20 11:07:16 PM AST  CMP 126 Computer Technology and Applications
# 90   2024/09/21 5:06:23 PM AST         CMP 101 Computer Information Literacy
# 91  2024/09/22 10:08:19 PM AST  CMP 126 Computer Technology and Applications
#
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Which course are you currently enrolled in?',
#        'What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]',
#        'What motivated you to seek a computing class at CCM? [To keep current in computing skills]',
#        'What motivated you to seek a computing class at CCM? [Career Advancement]',
#        'What motivated you to seek a computing class at CCM? [Career Change]',
#        'What motivated you to seek a computing class at CCM? [Professional Development]',
#        'What motivated you to seek a computing class at CCM? [Job Displacement]',
#        'What motivated you to seek a computing class at CCM? [Relocation]',
#        'What motivated you to seek a computing class at CCM? [IT Industry Certifications]',
#        'What motivated you to seek a computing class at CCM? [Financial]',
#        'What motivated you to seek a computing class at CCM? [Personal Enrichment]',
# ...

# %% [markdown]
# Now, we manipulate the data, making the column names shorter

# %%
new_columns = {
    'Timestamp': 'timestamp',
    'Which course are you currently enrolled in?': 'current_course',
    'What motivated you to seek a computing class at CCM? [It‚Äôs a required class for the degree I‚Äôm seeking]': 'required',
    'What motivated you to seek a computing class at CCM? [To keep current in computing skills]': 'current',
    'What motivated you to seek a computing class at CCM? [Career Advancement]': 'advancement',
    'What motivated you to seek a computing class at CCM? [Career Change]': 'change',
    'What motivated you to seek a computing class at CCM? [Professional Development]': 'development',
    'What motivated you to seek a computing class at CCM? [Job Displacement]': 'displacement',
    'What motivated you to seek a computing class at CCM? [Relocation]': 'relocation',
    'What motivated you to seek a computing class at CCM? [IT Industry Certifications]': 'certifications',
    'What motivated you to seek a computing class at CCM? [Financial]': 'financial',
    'What motivated you to seek a computing class at CCM? [Personal Enrichment]': 'enrichment',
    'What motivated you to seek a computing class at CCM? [Curiosity]': 'curiosity',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]': 'openhouse',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]': 'instant_decision',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]': 'oncampus_session',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [TItan\'s Tuesday Virtual Information Session]': 'titans_tuesday',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]': 'women_dare',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]': 'college_fair',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]': 'hs_class',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]': 'hs_club',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]': 'competitions',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Afterschool computing-related camp/program]': 'afterschool',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Summer computing related camp/program]': 'summer_camp',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]': 'ap_class',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]': 'dual_enrollment',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend influence]': 'family_influence',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend working in the computing field]': 'family_field',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [High school teacher or guidance counselor]': 'counselor',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Employer influence]': 'employer',
    'How did you hear about County College of Morris  [CCM Web site]': 'website',
    'How did you hear about County College of Morris  [Billboard]': 'billboard',
    'How did you hear about County College of Morris  [Television]': 'tv',
    'How did you hear about County College of Morris  [Radio]': 'radio',
    'How did you hear about County College of Morris  [Social Media]': 'social',
    'How did you hear about County College of Morris  [Community Event]': 'event',
    'How did you hear about County College of Morris  [Family member or friend]': 'word_of_mouth',
    'How did you hear about County College of Morris  [Employer]': 'employer_ccm',
    'How did you hear about County College of Morris  [Current student]': 'current_student',
    'How did you hear about County College of Morris  [Alumni]': 'alumni',
    'How did you hear about County College of Morris  [High School]': 'high_school',
    'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]': 'cost',
    'To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]': 'location',
    'To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]': 'programs',
    'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]': 'online',
    'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]': 'referral',
    'To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]': 'faculty',
    'To what extent did the following impact your decision to attend County College of Morris? [College reputation]': 'reputation',
    'To what extent did the following impact your decision to attend County College of Morris? [Scholarships]': 'scholarships',
    'To what extent did the following impact your decision to attend County College of Morris? [Transfer student]': 'transfer',
    'To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]': 'class_size',
    'To what extent did the following impact your decision to attend County College of Morris? [Extra curricula opportunities]': 'activities',
    'What degree program are you currently enrolled in?': 'degree_program',
    'Did you receive information about our computing course from any of the following sources? [High school guidance counselor]': 'counselor_info',
    'Did you receive information about our computing course from any of the following sources? [CCM Information Technologies Website]': 'ccm_it_website',
    'Did you receive information about our computing course from any of the following sources? [CCM Admissions]': 'admissions',
    'Did you receive information about our computing course from any of the following sources? [CCM advisor/counselor]': 'ccm_counselor',
    'Did you receive information about our computing course from any of the following sources? [Employer]': 'employer_course',
    'Did you receive information about our computing course from any of the following sources? [Other]': 'other_info',
    'On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?': 'interest_level',
    'If you answered that you were interested in taking more computing classes, which ones interest you most? [Web Development]': 'web',
    'If you answered that you were interested in taking more computing classes, which ones interest you most? [CyberSecurity]': 'cybersecurity',
    'If you answered that you were interested in taking more computing classes, which ones interest you most? [App Development]': 'apps',
    'If you answered that you were interested in taking more computing classes, which ones interest you most? [Data Analytics]': 'analytics',
    'If you answered that you were interested in taking more computing classes, which ones interest you most? [Machine Learning/Artificial Intelligence]': 'ml_ai',
    'If you answered that you were interested in taking more computing classes, which ones interest you most? [Computer Programming]': 'programming',
    'If you answered that you were interested in taking more computing classes, which ones interest you most? [Game Design]': 'gamedev',
    'If you answered that you were interested in taking more computing classes, which ones interest you most? [Hardware Installation & Repair]': 'hardware',
    'Gender': 'gender',
    'Race/ethnicity': 'race_ethnicity',
    'Age ': 'age'
}

df.rename(columns=new_columns, inplace=True)
df.rename(columns={df.columns[2]: 'required'}, inplace=True) #we need to specifically rename this column because of the apostrophe. for some reason, Äôm doesn't register in the dictionary so this is the last resort

# %% [markdown]
# Dataset + columns AFTER manipulation:

# %%
df
# Out:
#                      timestamp                                current_course  \
# 0   2024/09/10 10:47:35 AM AST  CMP 126 Computer Technology and Applications
# 1   2024/09/10 11:00:05 AM AST  CMP 126 Computer Technology and Applications
# 2   2024/09/10 11:02:51 AM AST  CMP 126 Computer Technology and Applications
# 3   2024/09/10 11:05:25 AM AST  CMP 126 Computer Technology and Applications
# 4    2024/09/10 8:37:36 PM AST         CMP 101 Computer Information Literacy
# ..                         ...                                           ...
# 87  2024/09/20 10:55:34 PM AST         CMP 101 Computer Information Literacy
# 88  2024/09/20 11:02:45 PM AST  CMP 126 Computer Technology and Applications
# 89  2024/09/20 11:07:16 PM AST  CMP 126 Computer Technology and Applications
# 90   2024/09/21 5:06:23 PM AST         CMP 101 Computer Information Literacy
# 91  2024/09/22 10:08:19 PM AST  CMP 126 Computer Technology and Applications
#
# ...

# %%
df.columns
# Out:
# Index(['timestamp', 'current_course', 'required', 'current', 'advancement',
#        'change', 'development', 'displacement', 'relocation', 'certifications',
#        'financial', 'enrichment', 'curiosity', 'openhouse', 'instant_decision',
#        'oncampus_session', 'titans_tuesday', 'women_dare', 'college_fair',
#        'hs_class', 'hs_club', 'competitions', 'afterschool', 'summer_camp',
#        'ap_class', 'dual_enrollment', 'family_influence', 'family_field',
#        'counselor', 'employer', 'website', 'billboard', 'tv', 'radio',
#        'social', 'event', 'word_of_mouth', 'employer_ccm', 'current_student',
#        'alumni', 'high_school', 'cost', 'location', 'programs', 'online',
#        'referral', 'faculty', 'reputation', 'scholarships', 'transfer',
#        'class_size', 'activities', 'degree_program', 'counselor_info',
#        'ccm_it_website', 'admissions', 'ccm_counselor', 'employer_course',
#        'other_info', 'interest_level', 'web', 'cybersecurity', 'apps',
# ...

# %% [markdown]
# ## Let's get rid of unneccesary columns

# %% [markdown]
# Question 1: Are students that have taken a computing class prior to their CCM education more likely to voluntarily take a computing class at CCM? (hs_class, ap_class, dual_enrollment, interest_level)

# %% [markdown]
# Question 2: Which class is the most likely to be taken for someone's passion (personal enrichment or curiosity)? (current_course, enrichment, curiosity)

# %% [markdown]
# Question 3: Which programs have the most students who are enthusiastic about computer science? (interest_level, degree_program)

# %% [markdown]
# Question 4: Which specific computer science classes have the most interest? (web, cybersecurity, apps, analytics, ml_ai, programming, gamedev, hardware, interest_level)

# %% [markdown]
# Question 5: What age group is the least enthusiastic about computer science? (age, interest_level)

# %% [markdown]
# Columns needed:
# hs_class, ap_class, dual_enrollment, interest_level, current_course, enrichment, curiosity, degree_program, age, web, cybersecurity, apps, analytics, ml_ai, programming, gamedev, hardware

# %%
keep = ['hs_class', 'ap_class', 'dual_enrollment', 'interest_level', 'current_course', 'enrichment', 'curiosity', 'degree_program', 'age', 'web', 'cybersecurity', 'apps', 'analytics', 'ml_ai', 'programming', 'gamedev', 'hardware']
df_sub = df[keep]

# %% [markdown]
# Now, here is the final csv file and columns

# %%
df_sub
# Out:
#        hs_class     ap_class dual_enrollment  interest_level  \
# 0     No Impact          NaN             NaN               2
# 1   Some Impact  Some Impact     Some Impact               3
# 2           NaN          NaN             NaN               5
# 3     No Impact    No Impact       No Impact               3
# 4   Some Impact          NaN             NaN               3
# ..          ...          ...             ...             ...
# 87  Some Impact  Some Impact     High Impact               3
# 88    No Impact    No Impact       No Impact               3
# 89    No Impact    No Impact       No Impact               1
# 90  High Impact    No Impact       No Impact               3
# 91  Some Impact    No Impact       No Impact               5
#
#                                   current_course enrichment curiosity  \
# 0   CMP 126 Computer Technology and Applications        Yes       Yes
# 1   CMP 126 Computer Technology and Applications        Yes       Yes
# ...

# %%
df_sub.columns
# Out:
# Index(['hs_class', 'ap_class', 'dual_enrollment', 'interest_level',
#        'current_course', 'enrichment', 'curiosity', 'degree_program', 'age',
#        'web', 'cybersecurity', 'apps', 'analytics', 'ml_ai', 'programming',
#        'gamedev', 'hardware'],
#       dtype='object')

# %%
df_sub.to_csv('cleaned.csv')

# %% [markdown]
# p.s. does the degree program column really need to be cleaned up if there are no similar majors?
